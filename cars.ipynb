# %%
import pandas as pd

cars = pd.read_csv("data/cars.csv")

# %%
cars.head()
# Out:
#           Car       Model  Volume  Weight  CO2
# 0      Toyoty        Aygo    1000     790   99
# 1  Mitsubishi  Space Star    1200    1160   95
# 2       Skoda      Citigo    1000     929   95
# 3        Fiat         500     900     865   90
# 4        Mini      Cooper    1500    1140  105

# %%
#get list of categorical variables
s = (cars.dtypes == 'object')
object_cols = list(s[s].index)

print('Categorical variables:')
print(object_cols)
# Out:
# Categorical variables:
# ['Car', 'Model']

# %%
import pandas as pd
import numpy as np
 
#Create a DataFrame
df1 = {
    'Name':['George','Andrea','micheal','maggie','Ravi','Xien','Jalpa',np.nan],
    'State':['Arizona','Georgia','Newyork','Indiana','Florida','California',np.nan,np.nan],
    'Gender':["M","F","M","F","M","M",np.nan,np.nan],      
    'Score':[63,48,56,75,np.nan,77,np.nan,np.nan]
     
   }
 
df1 = pd.DataFrame(df1,columns=['Name','State','Gender','Score'])
print(df1)
# Out:
#       Name       State Gender  Score
# 0   George     Arizona      M   63.0
# 1   Andrea     Georgia      F   48.0
# 2  micheal     Newyork      M   56.0
# 3   maggie     Indiana      F   75.0
# 4     Ravi     Florida      M    NaN
# 5     Xien  California      M   77.0
# 6    Jalpa         NaN    NaN    NaN
# 7      NaN         NaN    NaN    NaN

# %%
df1.dropna(inplace=True)

# %%
state_index = df1.dropna(thresh=2).dropna(subset=['Score']).set_index(['State'])

# %%
state_index.reset_index()
# Out:
#         State     Name Gender  Score
# 0     Arizona   George      M   63.0
# 1     Georgia   Andrea      F   48.0
# 2     Newyork  micheal      M   56.0
# 3     Indiana   maggie      F   75.0
# 4  California     Xien      M   77.0

# %%
df1
# Out:
#       Name       State Gender  Score
# 0   George     Arizona      M   63.0
# 1   Andrea     Georgia      F   48.0
# 2  micheal     Newyork      M   56.0
# 3   maggie     Indiana      F   75.0
# 5     Xien  California      M   77.0

# %%
employee_by_gender = df1.pivot_table("Score", index="Name", columns="Gender")

# %%
employee_by_gender
# Out:
# Gender      F     M
# Name
# Andrea   48.0   NaN
# George    NaN  63.0
# Xien      NaN  77.0
# maggie   75.0   NaN
# micheal   NaN  56.0

# %%
cars.head()
# Out:
#           Car       Model  Volume  Weight  CO2
# 0      Toyoty        Aygo    1000     790   99
# 1  Mitsubishi  Space Star    1200    1160   95
# 2       Skoda      Citigo    1000     929   95
# 3        Fiat         500     900     865   90
# 4        Mini      Cooper    1500    1140  105

# %%
cars_by_model = cars.pivot_table("Volume",index="Car", columns="Weight",fill_value="999")
